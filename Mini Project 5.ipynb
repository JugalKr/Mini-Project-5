# %%
import pandas as pd
import numpy as np
from tkinter import*
import random
import os
from tkinter import messagebox

class Bill_App:
    def __init__(self, root,):
        self.root = root
        self.root.geometry("1350x700+0+0")
        self.root.title("Jugal Kr")
bg_color = "#1f1c4d"
title = Label(self.root, text ="Paradise Billing Dashboard",font =('times new roman', 30, 'bold'), pady=2, bd=12, bg="#1f1c4d",fg="White", relief=GROOVE)
title.pack(fill=X)



self.paneer_roll = IntVar()
self.chicken_roll = IntVar()
self.chilli_potato = IntVar()
self.egg_roll = IntVar()
self.chilli_chicken = IntVar()

self.lime_juice = IntVar()
self.mojito = IntVar()
self.oreo_shake = IntVar()
self.chocolate_shake = IntVar()
self.mango_shake = IntVar()




self.fast_food_price = StringVar()
self.beverages_price = StringVar()



self.c_name = StringVar()
self.c_phone = StringVar()
self.bill_no = StringVar()
x = random.randint(1000, 9999)
self.bill_no.set(str(x))
self.search_bill = StringVar()

self.fast_food_tax = StringVar()
self.beverages_tax = StringVar()


F1 = LabelFrame(self.root, text="Customer Details", font=('times new,roman', 15, 'bold'), bd=10, fg="White", bg="#1f1c4d")
F1.place(x=0, y=80, relwidth=1)


cname_lbl = Label(F1, text="Customer Name:", bg=bg_color, font=('times new roman', 15, 'bold'))
cname_lbl.grid(row=0, column=0, padx=20, pady=5)
cname_txt = Entry(F1, width=15, textvariable=self.c_name, font='arial 15', bd=7, relief=GROOVE)
cname_txt.grid(row=0, column=1, pady=5, padx=10)

cphn_lbl = Label(F1, text="Customer Phone:", bg="#1f1c4d", font=('times new roman', 15, 'bold'))
cphn_lbl.grid(row=0, column=2, padx=20, pady=5)
cphn_txt = Entry(F1, width=15, textvariable = self.c_phone, font='arial 15', bd=7, relief=GROOVE)
cphn_txt.grid(row=0, column=3, pady=5, padx=10)

c_bill_lbl = Label(F1, text="Bill Number:", bg="#1f1c4d", font=('times new roman', 15, 'bold'))
c_bill_lbl.grid(row=0, column=4, padx=20, pady=5)
c_bill_txt = Entry(F1, width=15, textvariable = self.search_bill,font='arial 15', bd=7, relief=GROOVE)
c_bill_txt.grid(row=0, column=5, pady=5, padx=10)

bil_btn = Button(F1, text="Search", command=self.find_bill, width=10,bd=7, font=('arial', 12, 'bold'), relief=GROOVE)
bil_btn.grid(row=0, column=6, pady=5, padx=10)



F2 = LabelFrame(self.root, text="Fast Food", font=('times new roman', 16, 'bold'), bd=10, fg="White", bg="#1f1c4d")
F2.place(x=5, y=180, width=325, height=380)


paneer_roll_lbl = Label(F2, text="Paneer Roll:", font=('times new roman',16, 'bold'), bg="#1f1c4d", fg="White")
paneer_roll_lbl.grid(row=0, column=0, padx=10, pady=10, sticky='W')
paneer_roll_txt = Entry(F2, width=10, textvariable = self.paneer_roll,font=('times new roman', 16, 'bold'), bd=5, relief=GROOVE)
paneer_roll_txt.grid(row=0, column=1, padx=10, pady=10)

chicken_roll_lbl = Label(F2, text="Chicken roll:", font=('times new roman', 16,'bold'), bg="#1f1c4d", fg="White")
chicken_roll_lbl.grid(row=1, column=0, padx=10, pady=10, sticky='W')
chicken_roll_txt = Entry(F2, width=10, textvariable = self.chicken_roll, font=('times new roman', 16, 'bold'), bd=5, relief=GROOVE)
chicken_roll_txt.grid(row=1, column=1, padx=10, pady=10)

chilli_potato_lbl = Label(F2, text="Chilli potato:", font=('times new roman', 16, 'bold'), bg="#1f1c4d", fg="White")
chilli_potato_lbl.grid(row=2, column=0, padx=10, pady=10, sticky='W')
chilli_potato_txt = Entry(F2, width=10, textvariable = self.chilli_potato,font=('times new roman', 16, 'bold'), bd=5, relief=GROOVE)
chilli_potato_txt.grid(row=2, column=1, padx=10, pady=10)

egg_roll_lbl = Label(F2, text="Egg roll:", font=('times new roman', 16,'bold'), bg="#1f1c4d", fg="White")
egg_roll_lbl.grid(row=3, column=0, padx=10, pady=10, sticky='W')
egg_roll_txt = Entry(F2, width=10, textvariable = self.egg_roll,font=('times new roman', 16, 'bold'), bd=5, relief=GROOVE)
egg_roll_txt.grid(row=3, column=1, padx=10, pady=10)

chilli_chicken_lbl = Label(F2, text="Chilli Chicken:", font=('times new roman', 16,'bold'), bg="#1f1c4d", fg="White")
chilli_chicken_lbl.grid(row=4, column=0, padx=10, pady=10, sticky='W')
chilli_chicken_txt = Entry(F2, width=10, textvariable = self.chilli_chicken,font=('times new roman', 16, 'bold'), bd=5, relief=GROOVE)
chilli_chicken_txt.grid(row=4, column=1, padx=10, pady=10)




F4 = LabelFrame(self.root, text="Beverages", font=('times new roman',16, 'bold'), bd=10, fg="White", bg="#1f1c4d")
F4.place(x=670, y=180, width=325, height=380)

lime_juice_lbl = Label(F4, text="Lime Juice:", font=('times new roman', 16,'bold'), bg="#1f1c4d", fg="White")
lime_juice_lbl.grid(row=0, column=0, padx=10, pady=10, sticky='W')
lime_juice_txt = Entry(F4, width=10, textvariable= self.lime_juice, font=('times new roman', 16, 'bold'), bd=5, relief=GROOVE)
lime_juice_txt.grid(row=0, column=1, padx=10, pady=10)

mojito_lbl = Label(F4, text="Mojito:", font=('times new roman', 16,'bold'), bg="#1f1c4d", fg="White")
mojito_lbl.grid(row=1, column=0, padx=10, pady=10, sticky='W')
mojito_txt = Entry(F4, width=10, textvariable= self.mojito,font=('times new roman', 16, 'bold'), bd=5, relief=GROOVE)
mojito_txt.grid(row=1, column=1, padx=10, pady=10)

oreo_shake_lbl = Label(F4, text="Oreo Shake:", font=('times new roman', 16,'bold'), bg="#1f1c4d", fg="White")
oreo_shake_lbl.grid(row=2, column=0, padx=10, pady=10, sticky='W')
oreo_shake_txt = Entry(F4, width=10, textvariable= self.oreo_shake, font=('times new roman', 16, 'bold'), bd=5, relief=GROOVE)
oreo_shake_txt.grid(row=2, column=1, padx=10, pady=10)

chocolate_shake_lbl = Label(F4, text="Chocolate Shake:", font=('times new roman', 16,'bold'), bg="#1f1c4d", fg="White")
chocolate_shake_lbl.grid(row=3, column=0, padx=10, pady=10, sticky='W')
chocolate_shake_txt = Entry(F4, width=10, textvariable= self.chocolate_shake, font=('times,new roman', 16, 'bold'), bd=5, relief=GROOVE)
chocolate_shake_txt.grid(row=3, column=1, padx=10, pady=10)

mango_shake_lbl = Label(F4, text="Mango Shake:", font=('times new roman', 16,'bold'), bg="#1f1c4d", fg="White")
mango_shake_lbl.grid(row=4, column=0, padx=10, pady=10, sticky='W')
mango_shake_txt = Entry(F4, width=10, textvariable= self.mango_shake, font=('times new roman', 16, 'bold'), bd=5, relief=GROOVE)
mango_shake_txt.grid(row=4, column=1, padx=10, pady=10)



F5 = Frame(self.root, bd=10, relief=GROOVE)
F5.place(x=1010, y=180, width=350, height=380)

bill_title = Label(F5, text="Bill Details Area", font='arial 15 bold',bd=7, relief=GROOVE)
bill_title.pack(fill=X)
scroll_y = Scrollbar(F5, orient=VERTICAL)
self.txtarea = Text(F5, yscrollcommand=scroll_y.set)
scroll_y.pack(side=RIGHT, fill=Y)
scroll_y.config(command=self.txtarea.yview)
self.txtarea.pack(fill=BOTH, expand=1)



F6 = LabelFrame(self.root, text="Bill Details Area", font=('times new roman', 14, 'bold'), bd=10, fg="White", bg="#1f1c4d")
F6.place(x=0, y=560, relwidth=1, height=140)

m1_lbl = Label(F6, text="Total Fast Food Price", font=('times new roman',14, 'bold'), bg="#120103", fg="red")
m1_lbl.grid(row=0, column=0, padx=20, pady=1, sticky='W')
m1_txt = Entry(F6, width=18, textvariable=self.medical_price,font='arial 10 bold', bd=7, relief=GROOVE)
m1_txt.grid(row=0, column=1, padx=18, pady=1)

m2_lbl = Label(F6, text="Total Beverages Price", font=('times new roman',14, 'bold'), bg="#120103", fg="red")
m2_lbl.grid(row=1, column=0, padx=20, pady=1, sticky='W')
m2_txt = Entry(F6, width=18, textvariable=self.grocery_price,font='arial 10 bold', bd=7, relief=GROOVE)
m2_txt.grid(row=1, column=1, padx=18, pady=1)

m3_lbl = Label(F6, text="Fast Food Tax", font=('times new roman', 14, 'bold'), bg="#120103", fg="red")
m3_lbl.grid(row=2, column=0, padx=20, pady=1, sticky='W')
m3_txt = Entry(F6, width=18, textvariable=self.beverages_price,font='arial 10 bold', bd=7, relief=GROOVE)
m3_txt.grid(row=2, column=1, padx=18, pady=1)

m4_lbl = Label(F6, text="Beverages Tax", font=('times new roman', 14,'bold'), bg="#120103", fg="red")
m4_lbl.grid(row=0, column=2, padx=20, pady=1, sticky='W')
m4_txt = Entry(F6, width=18, textvariable=self.medical_tax, font='arial 10 bold', bd=7, relief=GROOVE)
m4_txt.grid(row=0, column=3, padx=18, pady=1)



btn_f = Frame(F6, bd=7, relief=GROOVE)
btn_f.place(x=760, width=580, height=105)
total_btn = Button(btn_f, command=self.total, text="Total",bg="#1f1c4d", bd=2, fg="White", pady=15, width=12, font='arial 13 bold')
total_btn.grid(row=0, column=0, padx=5, pady=5)
generateBill_btn = Button(btn_f, command=self.bill_area, text="Generate Bill", bd=2, bg="#1f1c4d", fg="White", pady=12, width=12, font='arial 13 bold')
generateBill_btn.grid(row=0, column=1, padx=5, pady=5)


clear_btn = Button(btn_f, command=self.clear_data, text="Clear",bg="#1f1c4d", bd=2, fg="White", pady=15, width=12, font='arial 13 bold')
clear_btn.grid(row=0, column=2, padx=5, pady=5)
exit_btn = Button(btn_f, command=self.exit_app, text="Exit", bd=2,bg="#1f1c4d", fg="White", pady=15, width=12, font='arial 13 bold')
exit_btn.grid(row=0, column=3, padx=5, pady=5)
self.welcome_bill()

def total(self):
    
    self.f_p_r_p = self.paneer_roll.get()*45
    self.f_c_r_p = self.chicken_roll.get()*65
    self.f_c_p_p = self.chilli_potato.get()*60
    self.f_e_g_p = self.egg_roll.get()*50
    self.f_c_c_p = self.chilli_chicken.get()*180
    self.total_fast_food_price = float(self.f_s_p+self.f_f_p+self.f_h_g_p+self.f_de_p+self.f_d_p+self.f_t_g_p)
    self.fast_food_price.set("Rs. "+str(self.total_fast_food_price))
    self.fast_food_tax = round((self.total_fast_food_price*0.05), 2)
    self.fast_food_tax.set("Rs. "+str(self.f_tax))



    self.b_l_j_p = self.lime_juice.get()*40
    self.b_m_p = self.mojito.get()*80
    self.b_o_s_p = self.oreo_shake.get()*80
    self.b_c_s_p = self.chocolate_shake.get()*70
    self.b_m_s_p = self.mango_shake.get()*80
    self.total_beverages_price = float(self.b_l_j_p+self.b_m_p+self.b_o_s_p+self.b_c_s_p+self.b_m_s_p)
    self.beverages_price.set("Rs. "+str(self.total_beverages_price))
    self.beverages_tax = round((self.total_beverages_price*0.1), 2)
    self.beverages_tax.set("Rs. "+str(self.b__tax))
    self.total_bill = float(self.total_fast_food_price+self.total_beverages_price+self.f_tax+self+self.b__tax)


def welcome_bill(self):
    self.txtarea.delete('1.0', END)
    self.txtarea.insert(END, "\tWelcome To Fast Food center")
    self.txtarea.insert(END, f"\nBill Number:{self.bill_no.get()}")
    self.txtarea.insert(END, f"\nCustomer Name:{self.c_name.get()}")
    self.txtarea.insert(END, f"\nPhone Number{self.c_phone.get()}")
    self.txtarea.insert(END, f"\n================================")
    self.txtarea.insert(END, f"\nProducts\t\tQTY\t\tPrice")

def bill_area(self):
    if self.c_name.get() == " " or self.c_phone.get() == " ":
        messagebox.showerror("Error", "Customer Details Are Must")
    elif self.medical_price.get() == "Rs. 0.0" and self.grocery_price.get()== "Rs. 0.0" and self.beverages_price.get()=="Rs. 0.0":messagebox.showerror("Error", "No Product Purchased")
    else:
    
    
      self.welcome_bill()

if self.paneer_roll.get() != 0:
    self.txtarea.insert(END, f"\n paneer_roll\t\t{self.paneer_roll.get()}\t\t{self.f_p_r_p}")
if self.chicken_roll.get() != 0:
    self.txtarea.insert(END, f"\n chicken_roll\t\t{self.chicken_roll.get()}\t\t{self.f_c_r_p}")
if self.chilli_potato.get() != 0:
    self.txtarea.insert(END, f"\n chilli_potato\t\t{self.chilli_potato.get()}\t\t{self.f_c_p_p}")
if self.egg_roll.get() != 0:
    self.txtarea.insert(END, f"\n egg_roll\t\t{self.egg_roll.get()}\t\t{self.f_e_g_p}")
if self.chilli_chicken.get() != 0:
    self.txtarea.insert(END, f"\n chilli_chicken\t\t{self.chilli_chicken.get()}\t\t{self.f_c_c_p}")



if self.mojito.get() != 0:
    self.txtarea.insert(END, f"\n mojito\t\t{self.mojito.get()}\t\t{self.b_l_j_p}")
if self.oreo_shake.get() != 0:
    self.txtarea.insert(END, f"\n oreo_shake\t\t{self.oreo_shake.get()}\t\t{self.b_m_p}")
if self.mango_shake.get() != 0:
    self.txtarea.insert(END, f"\n mango_shake\t\t{self.mango_shake.get()}\t\t{self.b_o_s_p}")
if self.lime_juice.get() != 0:
    self.txtarea.insert(END, f"\n lime_juice\t\t{self.lime_juice.get()}\t\t{self.b_c_s_p}")
if self.chocolate_shake.get() != 0:
    self.txtarea.insert(END, f"\n chocolate_shake\t\t{self.chocolate_shake.get()}\t\t{self.b_m_s_p}")


self.txtarea.insert(END, f"\n--------------------------------")

if self.fast_food_tax.get() != '0.0':
    self.txtarea.insert(END, f"\n Fast Food Tax\t\t\t{self.fast_food_tax.get()}")

if self.beverages_tax.get() != '0.0':
    self.txtarea.insert(END, f"\n Beverages Tax\t\t\t{self.beverages_tax.get()}")
    self.txtarea.insert(END, f"\n Total Bill:\t\t\t Rs.{self.total_bill}")
    self.txtarea.insert(END, f"\n--------------------------------")
self.save_bill()

def save_bill(self):
    op = messagebox.askyesno("Save Bill", "Do you want to save the bill?")
if op > 0:
    self.bill_data = self.txtarea.get('1.0', END)
f1 = open("bills/"+str(self.bill_no.get())+".txt", "w")
f1.write(self.bill_data)
f1.close()
messagebox.showinfo("Saved", f"Bill no:{self.bill_no.get()} Saved Successfully")
  else:
    return


def find_bill(self):
    present = "no"
for i in os.listdir("bills/"):
    if i.split('.')[0] == self.search_bill.get():
        f1 = open(f"bills/{i}", "r")
    self.txtarea.delete("1.0", END)
for d in f1:
    self.txtarea.insert(END, d)
f1.close()
present = "yes"
if present == "no":def save_bill(self):

    messagebox.showerror("Error", "Invalid Bill No")

    
def clear_data(self):
    op = messagebox.askyesno("Clear", "Do you really want to Clear?")
if op > 0:
    self.paneer_roll.set(0)
    self.chicken_roll.set(0)
    self.chilli_potato.set(0)
    self.egg_roll.set(0)
    self.chilli_chicken.set(0)
    


    self.lime_juice.set(0)
    self.mojito.set(0)
    self.oreo_shake.set(0)
    self.chocolate_shake.set(0)
    self.mango_shake.set(0)
    

    self.fast_food_price.set("")
    self.beverages_price.set("")
    self.fast_food_tax.set("")
    self.beverages_tax.set("")
    self.c_name.set("")
    self.c_phone.set("")
    self.bill_no.set("")
x = random.randint(1000, 9999)
self.bill_no.set(str(x))
self.search_bill.set("")
self.welcome_bill()

def exit_app(self):
    op = messagebox.askyesno("Exit", "Do you really want to exit?")
if op > 0:
    self.root.destroy()

root = Tk()
obj = Bill_App(root)
root.mainloop()
# Out:
#   Input In [3]
#     else:
#     ^
# IndentationError: unexpected indent
